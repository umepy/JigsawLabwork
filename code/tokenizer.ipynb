# %%
from collections import defaultdict
import gensim
# %matplotlib inline
import matplotlib.pyplot as plt
import nltk
import numpy as np
import os
import pandas as pd
import random
import re
from nltk.corpus import sentiwordnet as swn
from tqdm import tqdm_notebook as tqdm

# 乱数の固定
SEED = 0
# word2vec を学習するか
train_word2vec = False
# text の前処理をするか
text_preprocessing = True
# MIN_COUNT に到達しない単語にも情報があれば付与したり，UNDEFINED などにしたほうが後々楽
MIN_COUNT = 10
debug = True
input_dir = os.path.join("..", "input")
jigsaw_path = "jigsaw-unintended-bias-in-toxicity-classification"
# Out:
# /opt/conda/lib/python3.6/site-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %%
train_df = pd.read_csv(os.path.join(input_dir, jigsaw_path, "train.csv"))
if debug:
    print("train columns", train_df.columns)
    print("train shape", train_df.shape)
train_df.head()
# Out:
# train columns Index(['id', 'target', 'comment_text', 'severe_toxicity', 'obscene',
#        'identity_attack', 'insult', 'threat', 'asian', 'atheist', 'bisexual',
#        'black', 'buddhist', 'christian', 'female', 'heterosexual', 'hindu',
#        'homosexual_gay_or_lesbian', 'intellectual_or_learning_disability',
#        'jewish', 'latino', 'male', 'muslim', 'other_disability',
#        'other_gender', 'other_race_or_ethnicity', 'other_religion',
#        'other_sexual_orientation', 'physical_disability',
#        'psychiatric_or_mental_illness', 'transgender', 'white', 'created_date',
#        'publication_id', 'parent_id', 'article_id', 'rating', 'funny', 'wow',
#        'sad', 'likes', 'disagree', 'sexual_explicit',
#        'identity_annotator_count', 'toxicity_annotator_count'],
#       dtype='object')
# train shape (1804874, 45)
#       id            ...             toxicity_annotator_count
# 0  59848            ...                                    4
# 1  59849            ...                                    4
# 2  59852            ...                                    4
# 3  59855            ...                                    4
# 4  59856            ...                                   47
#
# [5 rows x 45 columns]

# %%
test_df = pd.read_csv(os.path.join(input_dir, jigsaw_path, "test.csv"))
if debug:
    print("test columns", test_df.columns)
    print("test shape", test_df.shape)
test_df.head()
# Out:
# test columns Index(['id', 'comment_text'], dtype='object')
# test shape (97320, 2)
#         id                                       comment_text
# 0  7000000  Jeff Sessions is another one of Trump's Orwell...
# 1  7000001  I actually inspected the infrastructure on Gra...
# 2  7000002  No it won't . That's just wishful thinking on ...
# 3  7000003  Instead of wringing our hands and nibbling the...
# 4  7000004  how many of you commenters have garbage piled ...

# %%
all_document = train_df["comment_text"].tolist() + test_df["comment_text"].tolist()

# %%
# .The などが分かれないので，とりあえず .と大文字に対する分割
prog = re.compile('\.[A-Z]')
# 先頭大文字用
Head_check = re.compile('^[A-Z][^A-Z]+$')

# %%
URL_slash = re.compile('^//[A-Za-z/.]+')
URL_www = re.compile('^www[A-Za-z/.]+')

# %%
# 先頭大文字への対処．固有名詞には基本触れない
lemmatizer = nltk.stem.WordNetLemmatizer()
def word_compile(word, lemmatize = True):
    # 先頭のみ大文字
    if Head_check.match(word) is not None:
        word = word[0].lower() + word[1:]
    # URL の 統一
    elif URL_slash.match(word) is not None or URL_www.match(word):
        word = "URL_text"
    # 見出し語化
    if lemmatize:
        word = lemmatizer.lemmatize(word)
    return word

if debug:
    print(word_compile("They"))
    print(word_compile("TRUMP"))
    print(word_compile("WordNet"))
# Out:
# they
# TRUMP
# WordNet

# %%
# .が繋がっているとわかれないので
def splitter(text, split_words, include = True):
    split_words = [i.span()[0] for i in split_words]
    word_list = []
    word = ""
    for i in range(len(text)):
        word += text[i]
        if i in split_words:
            word_list.append(word_compile(word[:-1]))
            if include:
                word_list.append(".")
            word = ""
    word_list.append(word_compile(word))
    return word_list

if debug:
    print(splitter("borrow.Incoming", prog.finditer("borrow.Incoming")))
# Out:
# ['borrow', '.', 'incoming']

# %%
# sentence.split() はnltk.word_torknize(sentence) でも可
def tokenizer(sentence):
    global text_preprocessing
    if text_preprocessing:
        return [word_compile(word) if len(prog.findall(word)) == 0 else splitter(word, prog.finditer(word))[0] 
                      for word in nltk.word_tokenize(sentence)]
    else:
        return sentence.split()

sentences = [tokenizer(sentence) for sentence in all_document]
if debug:
    print(sentences[:2])
# Out:
# [['this', 'is', 'so', 'cool', '.', 'it', "'s", 'like', ',', "'would", 'you', 'want', 'your', 'mother', 'to', 'read', 'this', '?', '?', "'", 'really', 'great', 'idea', ',', 'well', 'done', '!'], ['thank', 'you', '!', '!', 'this', 'would', 'make', 'my', 'life', 'a', 'lot', 'le', 'anxiety-inducing', '.', 'keep', 'it', 'up', ',', 'and', 'do', "n't", 'let', 'anyone', 'get', 'in', 'your', 'way', '!']]

# %%
# 出現回数の少ない順にソート（確認のため）
word_count = defaultdict(lambda: 0)
if text_preprocessing:
    for sentence in sentences:
        for word in sentence:
            word_count[word] += 1
    word_count = dict(sorted(word_count.items(), key = lambda kv: kv[1]))

# %% [markdown]
# # タイプミスが非常に多い
# ネットスラングの方がまずいかなと思ったが，タイプミスや連続する文字の方がまずそう
#
# 全部は対応が厳しいので，一度 fasttext は試すべきかも

# %%
word_count
# Out:
# {'hahahahahahahahhha': 1,
#  'FFFFUUUUUUUUUUUUUUU': 1,
#  'better—it': 1,
#  'biased—I': 1,
#  'debate—we': 1,
#  'unpopular—so': 1,
#  'works—following': 1,
#  'Troll-In-Training': 1,
#  'insane-': 1,
#  'read*': 1,
#  'DIDENT': 1,
#  'DOWNHILL': 1,
#  'FLOURAIDE': 1,
#  'wmcelha': 1,
#  'tostones': 1,
#  'panopticomments': 1,
#  'bundycon': 1,
#  'troll-driven': 1,
#  'portland_hipster15': 1,
#  'mail.app': 1,
#  'x-webdoc': 1,
#  'bax': 1,
#  '.cowboys': 1,
#  'browsers..': 1,
#  'kigurmi': 1,
#  'sazac': 1,
#  'onzie': 1,
#  'appropiating': 1,
#  'vibers': 1,
#  'kumoricon': 1,
#  '.vary': 1,
#  'pizzicato': 1,
#  'commenter-facing': 1,
#  'Mr_Whiskers': 1,
#  'MrWhiskers1': 1,
#  '＼': 1,
#  '・ω・': 1,
#  'gluten-shame': 1,
#  'not-awfulness': 1,
#  'finGEred': 1,
#  'i-pAd': 1,
#  'top-most': 1,
#  'disruptively-steep': 1,
#  'floorpans': 1,
#  'burn/char': 1,
#  'founder/architect': 1,
#  'ell-oh-ell': 1,
#  'art-focused': 1,
#  'hungry…': 1,
#  'cibo': 1,
#  '🍕🍕🍕': 1,
#  'jail/etc': 1,
#  'IV-e': 1,
#  'people—either': 1,
#  'debate—even': 1,
#  'inche': 1,
#  'kabin': 1,
#  'email-leaking': 1,
#  'creativity-loving': 1,
#  'plantation-consciousness': 1,
#  '-wise': 1,
#  'dock-Yards': 1,
#  'KrisAnns': 1,
#  'jsilver': 1,
#  'aja_b': 1,
#  'parrot-thinking': 1,
#  'sparerib': 1,
#  'wi-if': 1,
#  'picatinny': 1,
#  'languishing-in-line-behind-the-chatty-person': 1,
#  'strict-vegetarian': 1,
#  'black/grey': 1,
#  'novisk': 1,
#  'dogowners': 1,
#  'race—the': 1,
#  '63,629': 1,
#  'glueck': 1,
#  'EXPLANATORY': 1,
#  'habitats–both': 1,
#  'globe–while': 1,
#  'hands-on-learning': 1,
#  'cage-like': 1,
#  '55-acre': 1,
#  'WWEEK': 1,
#  '7,00': 1,
#  'reefer-mad': 1,
#  'belville': 1,
#  'mobility-disabled': 1,
#  'displsyed': 1,
#  'adnire': 1,
#  'votedcfor': 1,
#  'much/fast': 1,
#  'news-breaking': 1,
#  'realigns': 1,
#  'vechchio': 1,
#  'then-zoo': 1,
#  'streetcars-': 1,
#  'fingers-in-my-ears': 1,
#  'deliciousness': 1,
#  'nonelitest': 1,
#  'vacasa': 1,
#  'TES': 1,
#  'unequivacally': 1,
#  'offiste': 1,
#  'strict/rude': 1,
#  'Anti-Displacement': 1,
#  'eco-apartheid': 1,
#  '350PDX': 1,
#  'ADPDX': 1,
#  "'surrender": 1,
#  'class-man': 1,
#  'america-like': 1,
#  'KOO-style': 1,
#  'unprecedented..': 1,
#  'qtip': 1,
#  'GATEKEEPERS': 1,
#  'closer…': 1,
#  'DETAILED': 1,
#  'teen-angst': 1,
#  'DystopianYA': 1,
#  'bit__': 1,
#  'HOLC': 1,
#  'ninety-hour': 1,
#  'two-hours': 1,
#  'anti-housing': 1,
#  'underproduced': 1,
#  'snobby-': 1,
#  '401k-': 1,
#  'KatieB': 1,
#  '1bath': 1,
#  'pbr': 1,
#  '08-3945': 1,
#  'seen/filmed': 1,
#  'vermontese': 1,
#  'article-worthy': 1,
#  'authorities/': 1,
#  'input-gave': 1,
#  'brownstei': 1,
#  'WIERDOS': 1,
#  'YES..': 1,
#  'densifying..': 1,
#  'glad..': 1,
#  'lumberjackish': 1,
#  'slobbery': 1,
#  'planning/quality': 1,
#  'brooklyndia': 1,
#  'silverlake': 1,
#  'nike/': 1,
#  'now-Portland': 1,
#  'CITM': 1,
#  'skanner': 1,
#  'ellerbee': 1,
#  'Cylvia-Gate': 1,
#  'anonymous5': 1,
#  'SAVER': 1,
#  'gowns…': 1,
#  'men—even': 1,
#  'dance-teacher.com': 1,
#  'MariaDi': 1,
#  'wearebernie': 1,
#  "'carpetbeggars": 1,
#  'CARPETBEGGARS': 1,
#  'groat': 1,
#  'paramilitaries/militias/': 1,
#  'lizlemon': 1,
#  'scam-worthy': 1,
#  'Slander/Libel': 1,
#  'streambanks': 1,
#  'density/walkability': 1,
#  'anti-displacement': 1,
#  'not-so-well': 1,
#  'hoping*': 1,
#  'funding—or': 1,
#  'be—is': 1,
#  'urbansim': 1,
#  'guard-llama': 1,
#  'plg': 1,
#  'COIs': 1,
#  'others/as': 1,
#  'CONTACTS': 1,
#  'Boise-Eliot': 1,
#  'Eliot/Irvington': 1,
#  "inter-gov't": 1,
#  'non-derogatory': 1,
#  'cannaball': 1,
#  'land—': 1,
#  'better-than-public-school': 1,
#  'Cease-and-Desist': 1,
#  "'hit-list": 1,
#  'NWAcademy': 1,
#  'threats..etc': 1,
#  'corporations/billionaires': 1,
#  'violations-': 1,
#  'scimps': 1,
#  's***-storm': 1,
#  'RETIRING': 1,
#  'doug~': 1,
#  'lisensure': 1,
#  'kit..': 1,
#  '=2016-knife-giveaway': 1,
#  'irrigon': 1,
#  'NPR\\PBS': 1,
#  'Archer-Daniels-Midland': 1,
#  'Under-Armor': 1,
#  'E-CON': 1,
#  'parenttryingtofindanswers': 1,
#  'anactual9thgradeparent': 1,
#  '/US/': 1,
#  '/OR/': 1,
#  'servicemark': 1,
#  'YES-vote': 1,
#  'occaisons': 1,
#  'patient-donors': 1,
#  "'reviewer": 1,
#  'white-racism': 1,
#  'Black-on-White': 1,
#  'Black-on-Asian': 1,
#  'plain-sight': 1,
#  'dock…': 1,
#  'ninth-grader': 1,
#  'non-hole': 1,
#  "'plushie": 1,
#  'kigurumi': 1,
#  'butt-inskys': 1,
#  'liysa': 1,
#  'MilitiaExtremists': 1,
#  'usp=form_confirm': 1,
#  'AirPlay': 1,
#  '~buskr': 1,
#  'be/continue': 1,
#  'hunkering-down': 1,
#  'classicism': 1,
#  'portland503': 1,
#  'v=Cp0I9qLE0VA': 1,
#  'v=EzFhWAcu3i0': 1,
#  'accessibility..': 1,
#  'option/responsibility': 1,
#  '300-unit': 1,
#  'bit.ly/23xnfC9': 1,
#  'bit.ly/23xnD3L': 1,
#  'entheogen': 1,
#  'emancipatenature': 1,
#  'tacticalshit': 1,
#  'MariaDi—I': 1,
#  'auto-reply': 1,
#  'ex-Moxie': 1,
#  'to/would': 1,
#  'pool/hot': 1,
#  'un-fenced': 1,
#  'green-way': 1,
#  'nietzsche-loving': 1,
#  'flaptrap': 1,
#  "'write-in": 1,
#  "'conciliatory": 1,
#  'nailon': 1,
#  'hiper': 1,
#  'cheese-covered': 1,
#  'cok': 1,
#  '618.': 1,
#  'quality/civility': 1,
#  'horse-riding': 1,
#  'superintndent': 1,
#  'VQ': 1,
#  'sewickleys': 1,
#  'sackhoff': 1,
#  'sewicky': 1,
#  'mega-condo': 1,
#  'ncluding': 1,
#  'RXdg': 1,
#  'ssr': 1,
#  'bicycle-themed': 1,
#  'beer-off': 1,
#  "he'she": 1,
#  'hellz': 1,
#  'accuserees': 1,
#  'jacquis': 1,
#  'spandex-free': 1,
#  'pseudo-scholarship': 1,
#  'spandexers': 1,
#  'quality..': 1,
#  'relevant/respectful': 1,
#  'kaletornado': 1,
#  'non-spandex': 1,
#  'QUIZZ': 1,
#  '-Future': 1,
#  'SPEKAING': 1,
#  'batterby': 1,
#  'HiMom': 1,
#  'recreationalise': 1,
#  'belgian-style': 1,
#  'emmon': 1,
#  'guilt/debt': 1,
#  'gospel—that': 1,
#  'annihilative': 1,
#  'corollary—the': 1,
#  'JWC': 1,
#  'satellite-assisted': 1,
#  'puss-filled': 1,
#  'PhD-level': 1,
#  'imporve': 1,
#  'aja.bog': 1,
#  'bottom-right': 1,
#  's0me': 1,
#  'micro-brick-and-mortar': 1,
#  'ActivSpace': 1,
#  'uncomfy': 1,
#  'historian/': 1,
#  'algorith': 1,
#  'auto-email': 1,
#  'naaahh': 1,
#  'spirited—so': 1,
#  "'coat": 1,
#  'e-editions': 1,
#  'W/Disqus': 1,
#  'w/option': 1,
#  'pop.up': 1,
#  "..'thumbs": 1,
#  'have/never': 1,
#  'ONward': 1,
#  'signed-in': 1,
#  '\ue014': 1,
#  'issues..anyone': 1,
#  'WayneKerr': 1,
#  'brick/mortar': 1,
#  'Progressive-Socialist-Leftwing': 1,
#  '2001-02': 1,
#  'compagni': 1,
#  'regrettably..': 1,
#  'MUPS': 1,
#  '4,735': 1,
#  '*frequent*': 1,
#  '814.400': 1,
#  'contibuting': 1,
#  '24,548': 1,
#  'employee-paid': 1,
#  '93/Veneta': 1,
#  "y'got": 1,
#  'a55hats': 1,
#  'a55hat': 1,
#  "'texture": 1,
#  'sno-park': 1,
#  'ideas—which': 1,
#  'Progressive-Socialist-Leftwind': 1,
#  '*REPOSTED*': 1,
#  "'Anecdote": 1,
#  'LTD/BEST': 1,
#  'atheist/agnostic': 1,
#  'funny—whether': 1,
#  'writers—I': 1,
#  'honest—I': 1,
#  '1,682': 1,
#  'avanti—it': 1,
#  'say—even': 1,
#  '—while': 1,
#  'greazzzzzzztzzzzzzz': 1,
#  'regulated/advice/actually': 1,
#  'atheist-': 1,
#  'theists-': 1,
#  'sewell-': 1,
#  'BrownBagsMatter': 1,
#  'hashtagbrownbagsmatter': 1,
#  "'Backpfeifengesicht": 1,
#  'deets': 1,
#  'southtown': 1,
#  'Oakway/Coburg': 1,
#  'backpfeifengesicht': 1,
#  'lizzyacker': 1,
#  'rubotio': 1,
#  'time_continue=28': 1,
#  'v=dqshYG4qvT4': 1,
#  'overtrained': 1,
#  'near-humanness': 1,
#  'tale-tale': 1,
#  'cooth': 1,
#  '14:1–4': 1,
#  'eisel': 1,
#  '22:8-15': 1,
#  '14:17-21': 1,
#  '10:10-15': 1,
#  '-new-': 1,
#  'cuonzo': 1,
#  'CompTIA': 1,
#  'home-grows': 1,
#  'soundcloud.com/whysirraps': 1,
#  'then/give': 1,
#  'respectful..outsider': 1,
#  'severity..': 1,
#  'atttitudes': 1,
#  'looney-toon': 1,
#  'ho-hos': 1,
#  'screen/': 1,
#  'SEMI-FACTUAL': 1,
#  'SUPERLATIVES': 1,
#  'perverted/distorted': 1,
#  'yataimura': 1,
#  'probation/parole*': 1,
#  '1.2/1.4': 1,
#  'had*': 1,
#  'tettering': 1,
#  'DuckTerritory.com': 1,
#  '•Morgan': 1,
#  '•Recipient': 1,
#  'kurdziel': 1,
#  '•Member': 1,
#  'i_pi': 1,
#  '.prefer': 1,
#  "'prospered": 1,
#  'situation/conversation': 1,
#  'JV/Varisty': 1,
#  'distorts/perverts': 1,
#  'kinel': 1,
#  'agricbusiness': 1,
#  'crime/jail': 1,
#  'jail/prison/probation': 1,
#  'andleaving': 1,
#  'rent-a-pet': 1,
#  'Veneta/Elmira': 1,
#  '120acres': 1,
#  ".'Civil": 1,
#  'mixed.': 1,
#  'corridors.': 1,
#  'ex-evangelical': 1,
#  'de-converted': 1,
#  'hitchins': 1,
#  'hudnut': 1,
#  'compactly': 1,
#  'bike-and-transit-friendly': 1,
#  'v=2W_yoeFJpsU': 1,
#  'w/few': 1,
#  'fru-fru': 1,
#  'approxametilie': 1,
#  'newdow': 1,
#  'non-pledging': 1,
#  'row-houses': 1,
#  'city-decreed': 1,
#  'bike/foot': 1,
#  'homiest': 1,
#  'gastronomically': 1,
#  'fits/bastardizes': 1,
#  'whore-mongering': 1,
#  'claimade': 1,
#  'zeda': 1,
#  'suburbanized': 1,
#  'reeeeallll': 1,
#  'sunny/windy': 1,
#  'SODHOUSE': 1,
#  '205-': 1,
#  'FlashAlert': 1,
#  'sodhouse': 1,
#  'pynes': 1,
#  'mentalites': 1,
#  'centurn': 1,
#  'video-capable': 1,
#  '500sqft': 1,
#  'shop/outbuilding': 1,
#  'intention/reason': 1,
#  'restorted': 1,
#  '*found*': 1,
#  'e-list': 1,
#  '6:30am-6pm': 1,
#  '5-7pm': 1,
#  'bundyland': 1,
#  'fatastisticism': 1,
#  'tfrank': 1,
#  "'takeover": 1,
#  '15,100,000': 1,
#  '9,900,000': 1,
#  'PPS*': 1,
#  'arrows.': 1,
#  'scotch-tape': 1,
#  'bunkerhill01': 1,
#  'BLM/USFS/Conservationist': 1,
#  'conservationsists': 1,
#  'schiefelbein': 1,
#  'ElizabethWarren2016': 1,
#  'hip/upper': 1,
#  '•Carbon': 1,
#  'pelicer': 1,
#  "bright'": 1,
#  'subjegates': 1,
#  'katrina-': 1,
#  'v=Qup47XJGIl4': 1,
#  'budaki': 1,
#  'hoeverboard': 1,
#  'eywitness': 1,
#  'BLAck': 1,
#  'interferometer': 1,
#  'most-demanding': 1,
#  'optical-coating': 1,
#  'tsake': 1,
#  'nickzukin': 1,
#  '10-cents-a-gallon': 1,
#  'libel…': 1,
#  'hover-board': 1,
#  'lavardo': 1,
#  'hover-boarders': 1,
#  'murder-even': 1,
#  'lab/storage': 1,
#  'Hype-Hype-HYPER': 1,
#  'adreneline': 1,
#  'fibbies': 1,
#  '40_20': 1,
#  "x'=x-vt": 1,
#  "y'=y": 1,
#  "z'=z": 1,
#  "t'=t": 1,
#  "y'": 1,
#  "z'": 1,
#  'unbottoned': 1,
#  'session._': 1,
#  'PRESENTING': 1,
#  'TWISTED': 1,
#  'OCCUPIERS': 1,
#  'malita': 1,
#  'feelings/paranoia': 1,
#  'premake': 1,
#  'domocracy': 1,
#  'AssClowns': 1,
#  'gun-battle': 1,
#  'rustystill': 1,
#  'it…I': 1,
#  'indianapolis-based': 1,
#  'ramps-up': 1,
#  'party-crashers': 1,
#  'malheurians': 1,
#  'behe': 1,
#  'FARM-OWNERS': 1,
#  'yokobayashi': 1,
#  'ghadiri': 1,
#  'self-replication': 1,
#  'hypercyclic': 1,
#  '591-4': 1,
#  'random-sequence': 1,
#  '715-718': 1,
#  'ekland': 1,
#  'ligases': 1,
#  '269.': 1,
#  '5222': 1,
#  'deamer': 1,
#  'ordeal..': 1,
#  '590,928': 1,
#  'comment-reply': 1,
#  'e-Edition': 1,
#  'approx..80,000': 1,
#  'homesteaders/Ranchers': 1,
#  'approx..185,000': 1,
#  'microevolution': 1,
#  'public/federal': 1,
#  'mega-governments': 1,
#  'discohesion': 1,
#  'sharpton.': 1,
#  '11-dimensional': 1,
#  'toroid': 1,
#  'destrucrive': 1,
#  'marionettists': 1,
#  "'Consent": 1,
#  'bork-type': 1,
#  'quasi-legislative': 1,
#  'sthash.s7CtdYl1.dpuf': 1,
#  'political/cultural/social': 1,
#  'politicians™': 1,
#  'issues-based': 1,
#  'flylooper': 1,
#  'history/context': 1,
#  'semi-person': 1,
#  '-Mitch': 1,
#  '.serve': 1,
#  'acromonious': 1,
#  'aggavate': 1,
#  '..ouch..': 1,
#  'marionettists.': 1,
#  'krauthhamer': 1,
#  'nescience': 1,
#  'chrade': 1,
#  'hicks.': 1,
#  'jense': 1,
#  'interstate-105': 1,
#  'mutation/': 1,
#  'post-or': 1,
#  'biocomplexity': 1,
#  'capital/socialist': 1,
#  'privitizes': 1,
#  'run-its-course': 1,
#  'change-\uf818denying': 1,
#  'DOLLARE': 1,
#  'CRU/IPCC': 1,
#  'USCRN': 1,
#  'HadAT2': 1,
#  'ARGUS': 1,
#  '105/aka': 1,
#  'high-poverty': 1,
#  'receieves': 1,
#  '^6': 1,
#  '5,000,000,000,000,000,000,000,000,000,000': 1,
#  'subfunctionalization': 1,
#  'quasi-legislator': 1,
#  'fast/passing': 1,
#  'slow/truck/right': 1,
#  "'accumulated": 1,
#  '…Google': 1,
#  'weinermans': 1,
#  '…initially': 1,
#  'back…sorry': 1,
#  'excedrin': 1,
#  'Harlow/Hayden': 1,
#  'already-oppressive': 1,
#  'voy..very': 1,
#  '___ists': 1,
#  'freakazoid': 1,
#  'reaction/public': 1,
#  '.decrease': 1,
#  'abslolutely': 1,
#  'idustrial': 1,
#  'Seattle/Olympia': 1,
#  'yippee-ki-yaay': 1,
#  'niqqers': 1,
#  'terroris': 1,
#  'sandniqqer': 1,
#  'riders/bills': 1,
#  'riders/': 1,
#  'low-particulate': 1,
#  'dope-dealers': 1,
#  'five-year-old*': 1,
#  'bradenton': 1,
#  'pan-hadler': 1,
#  '*drives': 1,
#  'ancient/': 1,
#  'treves': 1,
#  '32-minute': 1,
#  'v=7A5zpFQRBeE': 1,
#  'v=Hwny6gsyPWg': 1,
#  'list=PL9TrRLEAvvhZX4duPQejN29ChSMTKTwDa': 1,
#  'bud-rapid': 1,
#  'economically-mobile': 1,
#  'backspace': 1,
#  'Avenue/Washington-Jefferson': 1,
#  'Eugene-Springfield-Glenwood': 1,
#  '6.5Million': 1,
#  'letter-Jayme': 1,
#  'proceed—including': 1,
#  'post-founding': 1,
#  'understood—are': 1,
#  'way—but': 1,
#  'weinhards': 1,
#  'ecstacy/molly/MDMA': 1,
#  "court'": 1,
#  'ver-min': 1,
#  '-min': 1,
#  "'UN": 1,
#  'irresponsible……he': 1,
#  'DGJ': 1,
#  'luxuriance': 1,
#  'drafficking': 1,
#  'the1999': 1,
#  'retribution.': 1,
#  'either–too': 1,
#  'moderate-left': 1,
#  'from/live': 1,
#  'nonenzymatic': 1,
#  'dioxane': 1,
#  "'digging": 1,
#  'dine-in': 1,
#  'chopped-off': 1,
#  'asking/demanding/requesting': 1,
#  'intgrity': 1,
#  'asphyxiant': 1,
#  'acknowledgement/admiration': 1,
#  '_shared_': 1,
#  'influence/philosophy': 1,
#  'tanscribed': 1,
#  'post-playing': 1,
#  'AIRMOBILE': 1,
#  'zestier': 1,
#  'tomatoey': 1,
#  'breadier': 1,
#  'mastrigate': 1,
#  'incarcarate': 1,
#  '8the': 1,
#  'appolling': 1,
#  'proposition.': 1,
#  'Brentwood-Darlington': 1,
#  'digits-': 1,
#  '_elected_': 1,
#  'tim-tim': 1,
#  'handling-': 1,
#  'romain': 1,
#  'non-provoking': 1,
#  'housing/employment': 1,
#  'panhalding': 1,
#  'labor/owner/management': 1,
#  'employed-person': 1,
#  'well-sited': 1,
#  'FLASHBACK***MANCHESTER': 1,
#  'impact-tentacles': 1,
#  'biowarfare': 1,
#  'v=O-Mspl1XYUE': 1,
#  'down-arrow': 1,
#  'panhaldling': 1,
#  '8.0+': 1,
#  'insubordination.': 1,
#  'samll': 1,
#  'no-drinking': 1,
#  "'Sauce": 1,
#  'therepies': 1,
#  'fish/garden': 1,
#  'bundy-vidian': 1,
#  '.residential': 1,
#  'counseling/psychiatric': 1,
#  '_and': 1,
#  'gandering': 1,
#  '=dead=': 1,
#  'pandhandling': 1,
#  'madoff-type': 1,
#  'slum-level': 1,
#  'expofacto': 1,
#  'vidios': 1,
#  'LeVoye': 1,
#  'wheapons': 1,
#  'RfK': 1,
#  'JfK': 1,
#  'JlK': 1,
#  'name=terry+bean': 1,
#  'name=terry+shockley': 1,
#  'upsy-daisy': 1,
#  'hepzibah': 1,
#  'josphine': 1,
#  'telenovela': 1,
#  "the'70s": 1,
#  'affiable': 1,
#  'ChrisFrisella': 1,
#  'sepulvado': 1,
#  'ramire': 1,
#  'hmck': 1,
#  'photographer/videographer': 1,
#  'vinis.': 1,
#  'members-their': 1,
#  'other-way-around': 1,
#  'bummin': 1,
#  'public-used': 1,
#  'non-courteous': 1,
#  'SUTA': 1,
#  'GEARs': 1,
#  'all-road': 1,
#  'HONDA': 1,
#  'POSSESSION.2ND': 1,
#  'DOWNLOAD': 1,
#  'TTHEIR': 1,
#  'WEBSIGHT': 1,
#  'NEEDBE': 1,
#  'DEALINGS': 1,
#  'DCPD': 1,
#  'HE4E': 1,
#  'OccupyMovements': 1,
#  'D-Party': 1,
#  'lowercasepebble': 1,
#  "'civilly": 1,
#  "'uncivilly": 1,
#  'soulfood': 1,
#  'Electric/Hybrid': 1,
#  'carts/bikes': 1,
#  'proposals/legislation': 1,
#  'hoopsters': 1,
#  'Progressive/Democrat': 1,
#  'kruggo': 1,
#  'staf': 1,
#  'transparant': 1,
#  'GirlonTwoWheels': 1,
#  'teenager/early-20': 1,
#  'enidsptiz': 1,
#  'whaaaaaatttttt': 1,
#  'obstructed-view': 1,
#  '\xadbefore': 1,
#  'McMenemins': 1,
#  'dwellars': 1,
#  'hypocrita': 1,
#  'schutzhund': 1,
#  'off-coal': 1,
#  'TruNorth': 1,
#  'carpetbeggars': 1,
#  'eeeeeewwwwww': 1,
#  'housing/services': 1,
#  'respectical': 1,
#  '395,000.00': 1,
#  'city-against-the-public': 1,
#  '++considering': 1,
#  '80..': 1,
#  "'backdoor": 1,
#  'glass-house': 1,
#  'spoiler..so': 1,
#  "'tenor": 1,
#  'anitti-Vinis': 1,
#  'academically/socially/politically': 1,
#  "'sucking": 1,
#  'wolf-cries': 1,
#  'internet-of-things': 1,
#  'micro-jobs': 1,
#  'outsiderdom': 1,
#  'siphon-off': 1,
#  '-Flossie': 1,
#  'handout-': 1,
#  "'Ornia": 1,
#  'Taiwanese-American': 1,
#  'undomiciled': 1,
#  'ICCA': 1,
#  'unutilized': 1,
#  'up/raped': 1,
#  'capicola': 1,
#  'JRod014': 1,
#  "'flower": 1,
#  'now..he': 1,
#  'DogLady': 1,
#  'regidter': 1,
#  'OPTA': 1,
#  '1000-yard-stare': 1,
#  'directally': 1,
#  'private/commercially': 1,
#  'D-Scappoose': 1,
#  'seniors..perhaps': 1,
#  'worker.': 1,
#  "'truce": 1,
#  'v=wN7KHWdyrbI': 1,
#  'advisor/preparer': 1,
#  'overbrake': 1,
#  'jollee': 1,
#  '300-mile': 1,
#  'pre-1941': 1,
#  'e/o': 1,
#  '0YIuWGlt': 1,
#  '/1533368213500270883.jpg': 1,
#  'junnelle': 1,
#  'bernie-extremists': 1,
#  'hillary-extremists': 1,
#  'safety/criminal': 1,
#  'craig-': 1,
#  'rear-window': 1,
#  'P-R-O-B-L-E-M': 1,
#  'oregoncraig': 1,
#  'HWY99': 1,
#  'exterminists': 1,
#  'foodlike': 1,
#  'computer-machines': 1,
#  'eugenicize': 1,
#  'marlene-': 1,
#  'new-driver': 1,
#  'affecxt': 1,
#  'annnnnnnd': 1,
#  'GDL': 1,
#  'birky': 1,
#  'helvey': 1,
#  "'carp": 1,
#  'Again—Risking': 1,
#  'laisez-fair': 1,
#  'willkams': 1,
#  'v=t_KiHRHwaAs': 1,
#  "'childrin": 1,
#  'employee/fundamentalist': 1,
#  'Mid-May': 1,
#  'fairfiled': 1,
#  'individual/organization': 1,
#  'individuals/organizations': 1,
#  '9.25/hour': 1,
#  'saucrestress': 1,
#  '24–21': 1,
#  'facxts': 1,
#  'belman': 1,
#  'meta-analysis.': 1,
#  '*Reached': 1,
#  'prosanski': 1,
#  'Two-Face': 1,
#  'Nike/U': 1,
#  'yassa': 1,
#  'Civil/unCivil': 1,
#  "support..'": 1,
#  'finally..he': 1,
#  "'superiors": 1,
#  'seasonal-related': 1,
#  'courts/professional': 1,
#  'CFalls': 1,
#  'surveys..': 1,
#  'ETIC': 1,
#  'constitionalists': 1,
#  'ferti': 1,
#  '2-vehicle': 1,
#  'two-vehicle': 1,
#  'accident/1': 1,
#  'OHhhhhh': 1,
#  'hery': 1,
#  'ePaper': 1,
#  'community-speak': 1,
#  '*self-imposed*': 1,
#  'ritzheimer': 1,
#  'houze': 1,
#  'irremedial': 1,
#  'spollen': 1,
#  '47-49': 1,
#  'grand.': 1,
#  'YouAreFunded': 1,
#  'nongs': 1,
#  'khao': 1,
#  'cooooooler': 1,
#  'huh-uh': 1,
#  'unsterile': 1,
#  'trackClown': 1,
#  '190+': 1,
#  'concerns/threats': 1,
#  'TotallyFunded': 1,
#  'scruffed': 1,
#  'attently': 1,
#  'lifted……..after': 1,
#  'imposed…..after': 1,
#  'vibrance': 1,
#  'micro-brewpub': 1,
#  '11,108': 1,
#  '9,878': 1,
#  'sponbergs': 1,
#  'leglslators': 1,
#  'hotel-owners': 1,
#  "'Couvians": 1,
#  'co-habitors': 1,
#  '..points': 1,
#  'saving/revenue': 1,
#  'innovating/close': 1,
#  'acknowledge/address': 1,
#  'haytruck': 1,
#  'readerboards': 1,
#  'mile.': 1,
#  'readerboard': 1,
#  'god-surrogate': 1,
#  'miracle-making': 1,
#  'jshowers': 1,
#  'couvians': 1,
#  'devloped': 1,
#  'scrupub': 1,
#  'RetroDemocratic': 1,
#  'demoplutocratic': 1,
#  'in-April': 1,
#  'homosexuality…just': 1,
#  'democrati': 1,
#  'wait..not': 1,
#  'somos': 1,
#  'egoistas': 1,
#  "'Couv": 1,
#  'points:1': 1,
#  'business-only': 1,
#  'COY': 1,
#  'tarczewski': 1,
#  'allonzo': 1,
#  'noncommunicative': 1,
#  'B_Carfree': 1,
#  'corn-feed': 1,
#  'hilsboro': 1,
#  'antigapper': 1,
#  'awile': 1,
#  'holyer': 1,
#  'blackeye': 1,
#  'C-Tran': 1,
#  'decisionwise': 1,
#  'TOOLBOX': 1,
#  'greenhills': 1,
#  'pay-the-administrators-first': 1,
#  'v=NJxmpTMGhU0': 1,
#  'C-Note': 1,
#  'scientifically-driven': 1,
#  'brown-ness': 1,
#  "'Ainsworths": 1,
#  'tuallitan': 1,
#  "BBQ's/smokers": 1,
#  'adrelinaline': 1,
#  'tightly-wound': 1,
#  '1.20.07': 1,
#  'freedomisntfree': 1,
#  'hit-a-ya': 1,
#  'whoshh': 1,
#  '*planning*': 1,
#  '199.5': 1,
#  'CHEAPER-': 1,
#  'data…not': 1,
#  'North/West': 1,
#  'zooming-out': 1,
#  'oid=22309': 1,
#  'deputees': 1,
#  'senaca': 1,
#  'refutal': 1,
#  'creepy-': 1,
#  'eldership': 1,
#  'soft-peddle': 1,
#  '*Bailey': 1,
#  'RandyLeonard': 1,
#  'slovic-': 1,
#  'page_id=19': 1,
#  'OOOOhhhh': 1,
#  'livelihoods/': 1,
#  'ODFG': 1,
#  'Patton/Vista': 1,
#  'progressive-but-misogynistic': 1,
#  'dog-stuffed': 1,
#  'suplexes': 1,
#  'piledrivers': 1,
#  'clothelines': 1,
#  'I-PI': 1,
#  ...}

# %%
# !pip list
# Out:
# Package                            Version                 Location
# ---------------------------------- ----------------------- --------------
# absl-py                            0.7.1
# alabaster                          0.7.10
# alembic                            1.0.9
# algopy                             0.5.7
# altair                             2.4.1
# anaconda-client                    1.6.14
# anaconda-navigator                 1.8.7
# anaconda-project                   0.8.2
# annoy                              1.15.2
# appdirs                            1.4.3
# arrow                              0.13.1
# asn1crypto                         0.24.0
# astor                              0.7.1
# astroid                            1.6.3
# astropy                            3.0.2
# attrs                              18.1.0
# audioread                          2.1.6
# Babel                              2.5.3
# backcall                           0.1.0
# backports.shutil-get-terminal-size 1.0.0
# Baker                              1.3
# basemap                            1.2.0
# bayesian-optimization              1.0.1
# bayespy                            0.5.18
# bcolz                              1.2.1
# beautifulsoup4                     4.6.0
# biopython                          1.73
# bitarray                           0.8.1
# bkcharts                           0.2
# blaze                              0.11.3
# bleach                             2.1.3
# blis                               0.2.4
# blist                              1.3.6
# bokeh                              1.1.0
# Boruta                             0.1.5
# boto                               2.48.0
# boto3                              1.9.134
# botocore                           1.12.134
# Bottleneck                         1.2.1
# bq-helper                          0.4.1                   /src/bq-helper
# branca                             0.3.1
# brewer2mpl                         1.4.1
# bz2file                            0.98
# cachetools                         3.1.0
# cairocffi                          file-.cairocffi-VERSION
# CairoSVG                           2.3.1
# Cartopy                            0.17.0
# catboost                           0.14.2
# category-encoders                  1.3.0
# certifi                            2019.3.9
# cesium                             0.9.9
# cffi                               1.11.5
# chainer                            5.4.0
# chainercv                          0.12.0
# chardet                            3.0.4
# cleverhans                         3.0.1
# Click                              7.0
# click-plugins                      1.1.1
# cliff                              2.14.1
# cligj                              0.5.0
# cloudpickle                        0.5.3
# clyent                             1.2.2
# cmd2                               0.9.12
# cmudict                            0.4.2
# colorama                           0.3.9
# colorcet                           2.0.1
# colorlog                           4.0.2
# colorlover                         0.3.0
# conda                              4.6.14
# conda-build                        3.10.5
# conda-verify                       2.0.0
# ConfigArgParse                     0.14.0
# contextlib2                        0.5.5
# convertdate                        2.1.3
# conx                               3.7.7
# coverage                           4.5.3
# cryptography                       2.2.2
# cssselect2                         0.2.1
# cufflinks                          0.15
# CVXcanon                           0.1.1
# cvxpy                              1.0.21
# cycler                             0.10.0
# cymem                              2.0.2
# cysignals                          1.10.2
# Cython                             0.29.7
# cytoolz                            0.9.0.1
# dask                               1.2.0
# dask-glm                           0.2.0
# dask-ml                            0.12.0
# dask-xgboost                       0.1.5
# dataclasses                        0.6
# datashader                         0.7.0
# datashape                          0.5.4
# deap                               1.2.2
# decorator                          4.3.0
# deepdish                           0.3.6
# defusedxml                         0.6.0
# Delorean                           1.0.0
# descartes                          1.1.0
# dill                               0.2.9
# dipy                               0.14.0
# distributed                        1.27.0
# docopt                             0.6.2
# docutils                           0.14
# dora                               0.1
# ecos                               2.0.5
# edward                             1.3.5
# eli5                               0.8.2
# emoji                              0.5.2
# en-core-web-lg                     2.1.0
# en-core-web-sm                     2.1.0
# entrypoints                        0.2.3
# enum34                             1.1.6
# ephem                              3.7.6.0
# essentia                           2.1b5.dev532
# et-xmlfile                         1.0.1
# ethnicolr                          0.2.0
# fancyimpute                        0.4.3
# fastai                             1.0.51
# fastcache                          1.0.2
# fasteners                          0.14.1
# fastFM                             0.2.11
# fastprogress                       0.1.21
# fasttext                           0.8.22
# fbpca                              1.0
# fbprophet                          0.4.post2
# feather-format                     0.4.0
# featuretools                       0.7.0
# filelock                           3.0.4
# Fiona                              1.8.6
# fitter                             1.0.9
# flake8                             3.6.0
# flashtext                          2.7
# Flask                              1.0.2
# Flask-Cors                         3.0.4
# flatbuffers                        1.10
# folium                             0.8.3
# ftfy                               4.4.3
# funcsigs                           1.0.2
# funcy                              1.12
# future                             0.17.1
# fuzzywuzzy                         0.17.0
# gast                               0.2.2
# gatspy                             0.3
# gdbn                               0.1
# gensim                             3.7.2
# geographiclib                      1.49
# Geohash                            1.0
# geojson                            2.4.1
# geopandas                          0.4.1
# geoplot                            0.2.4
# geopy                              1.19.0
# geoviews                           1.6.1
# gevent                             1.3.0
# ggplot                             0.11.5
# glmnet-py                          0.1.0b2
# glob2                              0.6
# gluoncv                            0.4.0.post0
# gluonnlp                           0.6.0
# gmpy2                              2.0.8
# gnumpy                             0.2
# google-api-core                    1.9.0
# google-api-python-client           1.7.8
# google-auth                        1.6.3
# google-auth-httplib2               0.0.3
# google-cloud-bigquery              1.11.2
# google-cloud-core                  0.29.1
# google-resumable-media             0.3.2
# googleapis-common-protos           1.5.9
# gplearn                            0.4.0
# gpxpy                              1.3.5
# graphviz                           0.8.4
# greenlet                           0.4.13
# grpcio                             1.20.0
# gym                                0.12.1
# h2o                                3.24.0.2
# h5py                               2.9.0
# hallucinate                        0.0.1
# haversine                          2.0.0
# heamy                              0.0.7
# heapdict                           1.0.0
# hep-ml                             0.6.0
# hmmlearn                           0.2.1
# holidays                           0.9.10
# holoviews                          1.12.1
# hpsklearn                          0.1.0
# html5lib                           1.0.1
# httplib2                           0.12.3
# humanize                           0.5.1
# hunspell                           0.5.5
# husl                               4.0.3
# hyperopt                           0.1.2
# hypertools                         0.5.1
# hypothesis                         4.17.2
# ibis-framework                     1.0.0
# idna                               2.6
# ijson                              2.3
# ImageHash                          4.0
# imageio                            2.3.0
# imagesize                          1.0.0
# imbalanced-learn                   0.5.0.dev0
# imgaug                             0.2.8
# implicit                           0.3.8
# ipykernel                          4.8.2
# ipython                            6.4.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.2.1
# iso3166                            1.0
# isort                              4.3.4
# isoweek                            1.3.3
# itsdangerous                       0.24
# Janome                             0.3.8
# jdcal                              1.4
# jedi                               0.12.0
# jieba                              0.39
# Jinja2                             2.10
# jmespath                           0.9.4
# joblib                             0.13.2
# jsonpickle                         0.9.6
# jsonschema                         2.6.0
# jupyter                            1.0.0
# jupyter-client                     5.2.3
# jupyter-console                    5.2.0
# jupyter-core                       4.4.0
# jupyter-tensorboard                0.1.9
# jupyterlab                         0.32.1
# jupyterlab-launcher                0.10.5
# Keras                              2.2.4
# Keras-Applications                 1.0.7
# Keras-Preprocessing                1.0.9
# keras-rcnn                         0.0.2
# keras-resnet                       0.1.0
# keras-rl                           0.4.2
# keras-tqdm                         2.0.1
# kiwisolver                         1.0.1
# kmapper                            1.2.0
# kmeans-smote                       0.1.2
# kmodes                             0.10.1
# knnimpute                          0.1.0
# ktext                              0.34
# langdetect                         1.0.7
# langid                             1.1.6
# Lasagne                            0.2.dev1
# lazy-object-proxy                  1.3.1
# learntools                         0.2.13
# leven                              1.0.4
# librosa                            0.6.3
# lightfm                            1.15
# lightgbm                           2.2.3
# lime                               0.1.1.33
# line-profiler                      2.1.2
# llvmlite                           0.23.1
# lml                                0.0.9
# locket                             0.2.0
# lunardate                          0.2.0
# lxml                               4.2.1
# lz4                                2.1.2
# Mako                               1.0.9
# marisa-trie                        0.7.5
# Markdown                           3.1
# markovify                          0.7.1
# MarkupSafe                         1.0
# matplotlib                         3.0.3
# matplotlib-venn                    0.11.5
# mccabe                             0.6.1
# memory-profiler                    0.55.0
# missingno                          0.4.1
# mistune                            0.8.3
# mizani                             0.5.4
# mkl-fft                            1.0.10
# mkl-random                         1.0.1
# ml-metrics                         0.1.4
# mlcrate                            0.2.0
# mlens                              0.2.3
# mlxtend                            0.16.0.dev0
# mmh3                               2.5.1
# mne                                0.17.2
# mnist                              0.2.2
# mock                               2.0.0
# monotonic                          1.5
# more-itertools                     4.1.0
# mpld3                              0.3
# mplleaflet                         0.0.5
# mpmath                             1.0.0
# msgpack                            0.6.1
# msgpack-numpy                      0.4.4.2
# msgpack-python                     0.5.6
# multipledispatch                   0.6.0
# multiprocess                       0.70.7
# munch                              2.3.2
# murmurhash                         1.0.0
# mxnet                              1.4.0.post0
# navigator-updater                  0.2.1
# nbconvert                          5.3.1
# nbformat                           4.4.0
# nervananeon                        2.6.0
# networkx                           2.1
# nibabel                            2.4.0
# nilearn                            0.5.2
# nltk                               3.2.4
# nolearn                            0.6.1.dev0
# nose                               1.3.7
# notebook                           5.5.0
# np-utils                           0.5.10.0
# numba                              0.38.0
# numdifftools                       0.9.20
# numexpr                            2.6.5
# numpy                              1.16.3
# numpydoc                           0.8.0
# nvidia-ml-py3                      7.352.0
# odfpy                              1.4.0
# odo                                0.5.1
# olefile                            0.45.1
# onnx                               1.4.1
# opencv-python                      4.1.0.25
# openpyxl                           2.5.3
# optuna                             0.10.0
# orderedmultidict                   1.0
# ortools                            7.0.6546
# osqp                               0.5.0
# packaging                          17.1
# palettable                         3.1.1
# pandas                             0.23.4
# pandas-datareader                  0.7.0
# pandas-profiling                   1.4.1
# pandas-summary                     0.0.6
# pandasql                           0.7.3
# pandoc                             1.0.2
# pandocfilters                      1.4.2
# param                              1.9.0
# paramnb                            2.0.4
# parso                              0.2.0
# partd                              0.3.8
# path.py                            11.0.1
# pathlib2                           2.3.2
# pathos                             0.2.3
# patsy                              0.5.0
# pbr                                5.1.3
# pdf2image                          1.5.1
# PDPbox                             0.2.0
# pep8                               1.7.1
# pexpect                            4.5.0
# pickleshare                        0.7.4
# Pillow                             5.1.0
# pip                                19.0.3
# pkginfo                            1.4.2
# plac                               0.9.6
# plotly                             3.8.1
# plotly-express                     0.1.7
# plotnine                           0.4.0
# pluggy                             0.6.0
# ply                                3.11
# polyglot                           16.7.4
# posix-ipc                          1.0.4
# pox                                0.2.5
# ppca                               0.0.4
# ppft                               1.6.4.9
# preprocessing                      0.1.13
# preshed                            2.0.1
# prettytable                        0.7.2
# progressbar2                       3.39.3
# prompt-toolkit                     1.0.15
# pronouncing                        0.2.0
# protobuf                           3.7.1
# psutil                             5.6.1
# ptyprocess                         0.5.2
# pudb                               2018.1
# py                                 1.5.3
# py-cpuinfo                         5.0.0
# py-lz4framed                       0.13.0
# py-stringmatching                  0.4.1
# py-stringsimjoin                   0.3.0
# pyahocorasick                      1.4.0
# PyArabic                           0.6.5
# pyarrow                            0.10.0
# pyasn1                             0.4.5
# pyasn1-modules                     0.2.5
# PyAstronomy                        0.13.0
# pybind11                           2.2.4
# PyBrain                            0.3.3
# pycairo                            1.18.0
# pycodestyle                        2.4.0
# pycosat                            0.6.3
# pycountry                          18.12.8
# pycparser                          2.18
# pycrypto                           2.6.1
# pyct                               0.4.6
# pycurl                             7.43.0.1
# pydash                             4.7.4
# pydicom                            1.2.2
# pydot                              1.4.1
# pyeconometrics                     1.0.2
# pyemd                              0.5.1
# pyexcel-io                         0.5.17
# pyexcel-ods                        0.5.6
# pyfasttext                         0.4.6
# pyflakes                           2.0.0
# pyflux                             0.4.15
# pyglet                             1.3.2
# Pygments                           2.2.0
# pykalman                           0.9.5
# pykoko                             0.1.8
# pyLDAvis                           2.1.2
# pylint                             1.8.4
# pymagnitude                        0.1.120
# pymc3                              3.6
# pymongo                            3.8.0
# Pympler                            0.7
# pyocr                              0.6
# pyodbc                             4.0.23
# PyOpenGL                           3.1.0
# pyOpenSSL                          18.0.0
# pypandoc                           1.4
# pyparsing                          2.2.0
# pyPdf                              1.13
# pyperclip                          1.7.0
# Pyphen                             0.9.5
# PyPrind                            2.11.2
# pyproj                             2.1.3
# pysal                              2.0.0
# pyshp                              2.1.0
# PySocks                            1.6.8
# pystan                             2.19.0.0
# pytagcloud                         0.3.5
# pytesseract                        0.2.6
# pytest                             3.5.1
# pytest-arraydiff                   0.2
# pytest-astropy                     0.3.0
# pytest-cov                         2.6.1
# pytest-doctestplus                 0.1.3
# pytest-mock                        1.10.4
# pytest-openfiles                   0.3.0
# pytest-remotedata                  0.2.1
# pytext-nlp                         0.1.2
# python-dateutil                    2.6.0
# python-editor                      1.0.4
# python-igraph                      0.7.1.post7
# python-Levenshtein                 0.12.0
# python-louvain                     0.13
# python-utils                       2.3.0
# pytz                               2018.4
# PyUpSet                            0.1.1.post7
# pyviz-comms                        0.7.2
# PyWavelets                         0.5.2
# PyYAML                             3.12
# pyzmq                              17.0.0
# QtAwesome                          0.4.4
# qtconsole                          4.3.1
# QtPy                               1.4.1
# raccoon                            2.1.5
# randomgen                          1.16.4
# ray                                0.6.6
# redis                              3.2.1
# regex                              2019.4.14
# requests                           2.21.0
# resampy                            0.2.1
# retrying                           1.3.3
# revrand                            0.6.5
# rf-perm-feat-import                0.1
# rgf-python                         3.5.0
# rope                               0.10.7
# rsa                                4.0
# ruamel-yaml                        0.15.35
# s2sphere                           0.2.5
# s3fs                               0.2.1
# s3transfer                         0.2.0
# sacred                             0.7.4
# scattertext                        0.0.2.48
# scikit-image                       0.15.0
# scikit-learn                       0.20.3
# scikit-multilearn                  0.2.0
# scikit-optimize                    0.5.2
# scikit-plot                        0.3.7
# scikit-surprise                    1.0.6
# scipy                              1.1.0
# scs                                2.1.0
# seaborn                            0.9.0
# Send2Trash                         1.5.0
# sentencepiece                      0.1.82
# setuptools                         39.1.0
# setuptools-git                     1.2
# shap                               0.28.5
# Shapely                            1.6.4.post2
# simplegeneric                      0.8.1
# SimpleITK                          1.2.0
# singledispatch                     3.4.0.3
# six                                1.12.0
# sklearn                            0.0
# sklearn-contrib-lightning          0.5.0
# sklearn-contrib-py-earth           0.1.0
# sklearn-pandas                     1.8.0
# smart-open                         1.8.2
# smhasher                           0.150.1
# snowballstemmer                    1.2.1
# sortedcollections                  0.6.1
# sortedcontainers                   1.5.10
# spacy                              2.1.3
# spectral                           0.19
# speedml                            0.9.3
# Sphinx                             1.7.4
# sphinx-rtd-theme                   0.2.4
# sphinxcontrib-websupport           1.0.1
# spyder                             3.2.8
# SQLAlchemy                         1.2.7
# squarify                           0.4.2
# srsly                              0.0.5
# statsmodels                        0.9.0
# stemming                           1.0.1
# stevedore                          1.30.1
# stop-words                         2018.7.23
# stopit                             1.1.2
# svgwrite                           1.2.1
# sympy                              1.1.1
# tables                             3.5.1
# tabulate                           0.8.3
# tblib                              1.3.2
# tensorboard                        1.13.1
# tensorboardX                       1.6
# tensorflow                         1.13.1
# tensorflow-estimator               1.13.0
# tensorflow-hub                     0.4.0
# tensorflow-probability             0.6.0
# tensorforce                        0.4.3
# tensorpack                         0.9.4
# termcolor                          1.1.0
# terminado                          0.8.1
# terminalplot                       0.2.6
# testpath                           0.3.1
# textacy                            0.6.2
# textblob                           0.15.3
# tflearn                            0.3.2
# Theano                             1.0.4+10.g9feed7868
# thinc                              7.0.4
# tifffile                           2019.3.18
# tinycss2                           1.0.2
# toolz                              0.9.0
# torch                              1.0.1.post2
# torchaudio                         0.2
# torchtext                          0.3.1
# torchvision                        0.2.2
# tornado                            5.0.2
# TPOT                               0.10.1
# tqdm                               4.31.1
# trackml                            0.1.12
# traitlets                          4.3.2
# trueskill                          0.4.5
# tsfresh                            0.11.2
# typing                             3.6.4
# typing-extensions                  3.7.2
# tzlocal                            1.5.1
# umap-learn                         0.3.8
# unicodecsv                         0.14.1
# Unidecode                          1.0.23
# update-checker                     0.16
# uritemplate                        3.0.0
# urllib3                            1.22
# urwid                              2.0.1
# vecstack                           0.3.0
# vega3                              0.13.0
# vida                               0.3
# visvis                             1.11.2
# vowpalwabbit                       8.5.0
# vtk                                8.1.2
# Wand                               0.5.3
# wasabi                             0.2.1
# wavio                              0.0.4
# wcwidth                            0.1.7
# webencodings                       0.5.1
# websocket-client                   0.56.0
# Werkzeug                           0.14.1
# wfdb                               2.2.1
# wheel                              0.31.1
# widgetsnbextension                 3.2.1
# Wordbatch                          1.3.8
# wordcloud                          1.5.0
# wordsegment                        1.3.1
# wrapt                              1.10.11
# xarray                             0.12.1
# xgboost                            0.82
# xlrd                               1.1.0
# XlsxWriter                         1.0.4
# xlwt                               1.3.0
# xvfbwrapper                        0.2.9
# xxhash                             1.3.0
# yellowbrick                        0.9.1
# zict                               0.1.3
